# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def apply_augmentation(image, method_index):
    if method_index == 0:
        # Rastgele döndürme
        angle = np.random.uniform(-30, 30)
        augmented_image = rotate_image(image, angle)
    elif method_index == 1:
        # Yatay ve dikey kaydırma
        height, width = image.shape[:2]
        tx = np.random.uniform(-0.05 * width, 0.05 * width)
        ty = np.random.uniform(-0.05 * height, 0.05 * height)
        augmented_image = shift_image(image, tx, ty)
    elif method_index == 2:
        # Parlaklık değişikliği
        brightness = np.random.uniform(0.2, 0.8)
        augmented_image = apply_brightness(image, brightness)
    elif method_index == 3:
        # Yakınlaştırma
        zoom = np.random.uniform(0.8, 1.2)
        augmented_image = zoom_image(image, zoom)
    elif method_index == 4:
        # Kanal kaydırma
        channel_shift_intensity = np.random.uniform(-0.2, 0.2)
        augmented_image = channel_shift(image, channel_shift_intensity)
    elif method_index == 5:
        # Gürültü ekleme
        noise_intensity = np.random.uniform(0, 0.1)
        augmented_image = add_noise(image, noise_intensity)
    elif method_index == 6:
        # Yatay çevirme
        augmented_image = flip_image(image, horizontal=True)
    elif method_index == 7:
        # Dikey çevirme
        augmented_image = flip_image(image, horizontal=False)
    else:
        augmented_image = image  # Varsayılan olarak orijinal resim
    
    return augmented_image

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, dx, dy):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, dx], [0, 1, dy]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def apply_brightness(image, brightness):
    image = image * brightness
    return np.clip(image, 0, 1)

def zoom_image(image, zoom):
    height, width = image.shape[:2]
    zoom_matrix = cv2.resize(image, None, fx=zoom, fy=zoom)
    zoom_height, zoom_width = zoom_matrix.shape[:2]

    start_x = max(zoom_width // 2 - width // 2, 0)
    start_y = max(zoom_height // 2 - height // 2, 0)
    end_x = start_x + width
    end_y = start_y + height

    zoom_image = zoom_matrix[start_y:end_y, start_x:end_x]
    return zoom_image

def channel_shift(image, intensity):
    image = image + intensity * np.std(image)
    return np.clip(image, 0, 1)

def add_noise(image, noise_intensity):
    noise = np.random.normal(0, noise_intensity, image.shape)
    noisy_image = image + noise
    return np.clip(noisy_image, 0, 1)

def flip_image(image, horizontal=True):
    if horizontal:
        return cv2.flip(image, 1)  # Yatay çevirme
    else:
        return cv2.flip(image, 0)  # Dikey çevirme

def augment_images_in_folder(input_folder, output_folder):
    # Giriş ve çıkış klasörlerinin mevcut olup olmadığını kontrol et
    if not os.path.exists(input_folder):
        raise FileNotFoundError(f"Giriş klasörü bulunamadı: {input_folder}")
    
    os.makedirs(output_folder, exist_ok=True)

    # Klasördeki tüm resim dosyalarını listeleme
    image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

    for image_file in image_files:
        image_path = os.path.join(input_folder, image_file)
        mr_image = cv2.imread(image_path)

        # Görüntünün doğru yüklendiğinden emin olun
        if mr_image is None:
            print(f"Görüntü yüklenemedi: {image_path}")
            continue

        # Görüntüyü yeniden boyutlandır
        mr_image_resized = cv2.resize(mr_image, (128, 128))

        # Görüntüyü gri tonlamalı hale getirin (gerekiyorsa)
        if len(mr_image_resized.shape) == 3 and mr_image_resized.shape[2] == 3:
            mr_image_gray = cv2.cvtColor(mr_image_resized, cv2.COLOR_BGR2GRAY)
        else:
            mr_image_gray = mr_image_resized

        # Görüntüyü normalizasyon işlemi (0-1 aralığına getirme)
        mr_image_normalized = mr_image_gray / 255.0

        # dokuz farklı arttırılmış resim oluşturalım ve kaydedelim
        augmented_images = []
        for i in range(9):
            augmented_image = apply_augmentation(mr_image_normalized, i)
            augmented_images.append(augmented_image)
            
            # Görüntüyü 0-255 aralığına geri döndür ve uint8 formatına dönüştür
            augmented_image_uint8 = (augmented_image * 255).astype(np.uint8)
            
            # Kaydet
            output_path = os.path.join(output_folder, f'{os.path.splitext(image_file)[0]}_augmented_{i+1}.png')
            cv2.imwrite(output_path, augmented_image_uint8)
        print(f"İşlenen görüntüler kaydedildi: {image_file}")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def apply_augmentation2(image, method_index):
    if method_index == 0:
        # Rastgele döndürme
        angle = np.random.uniform(-30, 30)
        augmented_image = rotate_image(image, angle)
    elif method_index == 1:
        # Yatay ve dikey kaydırma
        height, width = image.shape[:2]
        tx = np.random.uniform(-0.05 * width, 0.05 * width)
        ty = np.random.uniform(-0.05 * height, 0.05 * height)
        augmented_image = shift_image(image, tx, ty)
    elif method_index == 2:
        # Yatay çevirme
        augmented_image = flip_image(image, horizontal=True)
    elif method_index == 3:
        # Dikey çevirme
        augmented_image = flip_image(image, horizontal=False)
    else:
        augmented_image = image  # Varsayılan olarak orijinal resim
    
    return augmented_image

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, dx, dy):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, dx], [0, 1, dy]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def flip_image(image, horizontal=True):
    if horizontal:
        return cv2.flip(image, 1)  # Yatay çevirme
    else:
        return cv2.flip(image, 0)  # Dikey çevirme

def augment_images_in_folder2(input_folder, output_folder):
    # Giriş ve çıkış klasörlerinin mevcut olup olmadığını kontrol et
    if not os.path.exists(input_folder):
        raise FileNotFoundError(f"Giriş klasörü bulunamadı: {input_folder}")
    
    os.makedirs(output_folder, exist_ok=True)

    # Klasördeki tüm resim dosyalarını listeleme
    image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

    for image_file in image_files:
        image_path = os.path.join(input_folder, image_file)
        mr_image = cv2.imread(image_path)

        # Görüntünün doğru yüklendiğinden emin olun
        if mr_image is None:
            print(f"Görüntü yüklenemedi: {image_path}")
            continue

        # Görüntüyü yeniden boyutlandır
        mr_image_resized = cv2.resize(mr_image, (128, 128))

        # Görüntüyü gri tonlamalı hale getirin (gerekiyorsa)
        if len(mr_image_resized.shape) == 3 and mr_image_resized.shape[2] == 3:
            mr_image_gray = cv2.cvtColor(mr_image_resized, cv2.COLOR_BGR2GRAY)
        else:
            mr_image_gray = mr_image_resized

        # Görüntüyü normalizasyon işlemi (0-1 aralığına getirme)
        mr_image_normalized = mr_image_gray / 255.0

        # dokuz farklı arttırılmış resim oluşturalım ve kaydedelim
        augmented_images = []
        for i in range(2):
            augmented_image = apply_augmentation2(mr_image_normalized, i)
            augmented_images.append(augmented_image)
            
            # Görüntüyü 0-255 aralığına geri döndür ve uint8 formatına dönüştür
            augmented_image_uint8 = (augmented_image * 255).astype(np.uint8)
            
            # Kaydet
            output_path = os.path.join(output_folder, f'{os.path.splitext(image_file)[0]}_augmented_{i+1}.png')
            cv2.imwrite(output_path, augmented_image_uint8)
        print(f"İşlenen görüntüler kaydedildi: {image_file}")

# %%
input_folder = 'dataset_birlesik/label_0' # Giriş klasörü yolu
output_folder = 'dataset_birlesik/label_0_0'  # Çıkış klasörü yolu
augment_images_in_folder2(input_folder, output_folder)
# Out:
# İşlenen görüntüler kaydedildi: test_image_1.png
# İşlenen görüntüler kaydedildi: test_image_10.png
# İşlenen görüntüler kaydedildi: test_image_1009.png
# İşlenen görüntüler kaydedildi: test_image_1016.png
# İşlenen görüntüler kaydedildi: test_image_1018.png
# İşlenen görüntüler kaydedildi: test_image_1021.png
# İşlenen görüntüler kaydedildi: test_image_1032.png
# İşlenen görüntüler kaydedildi: test_image_1034.png
# İşlenen görüntüler kaydedildi: test_image_104.png
# İşlenen görüntüler kaydedildi: test_image_1048.png
# İşlenen görüntüler kaydedildi: test_image_1050.png
# İşlenen görüntüler kaydedildi: test_image_1053.png
# İşlenen görüntüler kaydedildi: test_image_1067.png
# İşlenen görüntüler kaydedildi: test_image_1069.png
# İşlenen görüntüler kaydedildi: test_image_107.png
# İşlenen görüntüler kaydedildi: test_image_1079.png
# İşlenen görüntüler kaydedildi: test_image_1095.png
# İşlenen görüntüler kaydedildi: test_image_1110.png
# İşlenen görüntüler kaydedildi: test_image_112.png
# İşlenen görüntüler kaydedildi: test_image_114.png
# İşlenen görüntüler kaydedildi: test_image_1140.png
# İşlenen görüntüler kaydedildi: test_image_1145.png
# İşlenen görüntüler kaydedildi: test_image_1166.png
# İşlenen görüntüler kaydedildi: test_image_1171.png
# İşlenen görüntüler kaydedildi: test_image_1173.png
# İşlenen görüntüler kaydedildi: test_image_1197.png
# İşlenen görüntüler kaydedildi: test_image_1201.png
# İşlenen görüntüler kaydedildi: test_image_121.png
# İşlenen görüntüler kaydedildi: test_image_122.png
# İşlenen görüntüler kaydedildi: test_image_1222.png
# İşlenen görüntüler kaydedildi: test_image_1225.png
# İşlenen görüntüler kaydedildi: test_image_1238.png
# İşlenen görüntüler kaydedildi: test_image_124.png
# İşlenen görüntüler kaydedildi: test_image_1240.png
# İşlenen görüntüler kaydedildi: test_image_1246.png
# İşlenen görüntüler kaydedildi: test_image_1249.png
# İşlenen görüntüler kaydedildi: test_image_125.png
# İşlenen görüntüler kaydedildi: test_image_1251.png
# İşlenen görüntüler kaydedildi: test_image_1264.png
# İşlenen görüntüler kaydedildi: test_image_1266.png
# İşlenen görüntüler kaydedildi: test_image_1267.png
# İşlenen görüntüler kaydedildi: test_image_127.png
# İşlenen görüntüler kaydedildi: test_image_1271.png
# İşlenen görüntüler kaydedildi: test_image_131.png
# İşlenen görüntüler kaydedildi: test_image_133.png
# İşlenen görüntüler kaydedildi: test_image_136.png
# İşlenen görüntüler kaydedildi: test_image_148.png
# İşlenen görüntüler kaydedildi: test_image_152.png
# İşlenen görüntüler kaydedildi: test_image_156.png
# İşlenen görüntüler kaydedildi: test_image_157.png
# İşlenen görüntüler kaydedildi: test_image_162.png
# İşlenen görüntüler kaydedildi: test_image_171.png
# İşlenen görüntüler kaydedildi: test_image_174.png
# İşlenen görüntüler kaydedildi: test_image_18.png
# İşlenen görüntüler kaydedildi: test_image_183.png
# İşlenen görüntüler kaydedildi: test_image_207.png
# İşlenen görüntüler kaydedildi: test_image_213.png
# İşlenen görüntüler kaydedildi: test_image_218.png
# İşlenen görüntüler kaydedildi: test_image_228.png
# İşlenen görüntüler kaydedildi: test_image_241.png
# İşlenen görüntüler kaydedildi: test_image_243.png
# İşlenen görüntüler kaydedildi: test_image_245.png
# İşlenen görüntüler kaydedildi: test_image_246.png
# İşlenen görüntüler kaydedildi: test_image_256.png
# İşlenen görüntüler kaydedildi: test_image_291.png
# İşlenen görüntüler kaydedildi: test_image_296.png
# İşlenen görüntüler kaydedildi: test_image_304.png
# İşlenen görüntüler kaydedildi: test_image_312.png
# İşlenen görüntüler kaydedildi: test_image_32.png
# İşlenen görüntüler kaydedildi: test_image_325.png
# İşlenen görüntüler kaydedildi: test_image_326.png
# İşlenen görüntüler kaydedildi: test_image_332.png
# İşlenen görüntüler kaydedildi: test_image_335.png
# İşlenen görüntüler kaydedildi: test_image_337.png
# İşlenen görüntüler kaydedildi: test_image_343.png
# İşlenen görüntüler kaydedildi: test_image_345.png
# İşlenen görüntüler kaydedildi: test_image_348.png
# İşlenen görüntüler kaydedildi: test_image_362.png
# İşlenen görüntüler kaydedildi: test_image_366.png
# İşlenen görüntüler kaydedildi: test_image_370.png
# İşlenen görüntüler kaydedildi: test_image_377.png
# İşlenen görüntüler kaydedildi: test_image_4.png
# İşlenen görüntüler kaydedildi: test_image_401.png
# İşlenen görüntüler kaydedildi: test_image_406.png
# İşlenen görüntüler kaydedildi: test_image_417.png
# İşlenen görüntüler kaydedildi: test_image_429.png
# İşlenen görüntüler kaydedildi: test_image_431.png
# İşlenen görüntüler kaydedildi: test_image_452.png
# İşlenen görüntüler kaydedildi: test_image_458.png
# İşlenen görüntüler kaydedildi: test_image_460.png
# İşlenen görüntüler kaydedildi: test_image_467.png
# İşlenen görüntüler kaydedildi: test_image_469.png
# İşlenen görüntüler kaydedildi: test_image_481.png
# İşlenen görüntüler kaydedildi: test_image_49.png
# İşlenen görüntüler kaydedildi: test_image_501.png
# İşlenen görüntüler kaydedildi: test_image_510.png
# İşlenen görüntüler kaydedildi: test_image_528.png
# İşlenen görüntüler kaydedildi: test_image_529.png
# İşlenen görüntüler kaydedildi: test_image_532.png
# İşlenen görüntüler kaydedildi: test_image_536.png
# İşlenen görüntüler kaydedildi: test_image_537.png
# İşlenen görüntüler kaydedildi: test_image_559.png
# İşlenen görüntüler kaydedildi: test_image_560.png
# İşlenen görüntüler kaydedildi: test_image_561.png
# İşlenen görüntüler kaydedildi: test_image_569.png
# İşlenen görüntüler kaydedildi: test_image_577.png
# İşlenen görüntüler kaydedildi: test_image_59.png
# İşlenen görüntüler kaydedildi: test_image_599.png
# İşlenen görüntüler kaydedildi: test_image_603.png
# İşlenen görüntüler kaydedildi: test_image_604.png
# İşlenen görüntüler kaydedildi: test_image_608.png
# İşlenen görüntüler kaydedildi: test_image_617.png
# İşlenen görüntüler kaydedildi: test_image_618.png
# İşlenen görüntüler kaydedildi: test_image_626.png
# İşlenen görüntüler kaydedildi: test_image_629.png
# İşlenen görüntüler kaydedildi: test_image_646.png
# İşlenen görüntüler kaydedildi: test_image_65.png
# İşlenen görüntüler kaydedildi: test_image_651.png
# İşlenen görüntüler kaydedildi: test_image_652.png
# İşlenen görüntüler kaydedildi: test_image_657.png
# İşlenen görüntüler kaydedildi: test_image_662.png
# İşlenen görüntüler kaydedildi: test_image_663.png
# İşlenen görüntüler kaydedildi: test_image_675.png
# İşlenen görüntüler kaydedildi: test_image_694.png
# İşlenen görüntüler kaydedildi: test_image_695.png
# İşlenen görüntüler kaydedildi: test_image_698.png
# İşlenen görüntüler kaydedildi: test_image_709.png
# İşlenen görüntüler kaydedildi: test_image_711.png
# İşlenen görüntüler kaydedildi: test_image_713.png
# İşlenen görüntüler kaydedildi: test_image_716.png
# İşlenen görüntüler kaydedildi: test_image_720.png
# İşlenen görüntüler kaydedildi: test_image_763.png
# İşlenen görüntüler kaydedildi: test_image_765.png
# İşlenen görüntüler kaydedildi: test_image_772.png
# İşlenen görüntüler kaydedildi: test_image_781.png
# İşlenen görüntüler kaydedildi: test_image_797.png
# İşlenen görüntüler kaydedildi: test_image_799.png
# İşlenen görüntüler kaydedildi: test_image_800.png
# İşlenen görüntüler kaydedildi: test_image_803.png
# İşlenen görüntüler kaydedildi: test_image_808.png
# İşlenen görüntüler kaydedildi: test_image_814.png
# İşlenen görüntüler kaydedildi: test_image_816.png
# İşlenen görüntüler kaydedildi: test_image_820.png
# İşlenen görüntüler kaydedildi: test_image_821.png
# İşlenen görüntüler kaydedildi: test_image_826.png
# İşlenen görüntüler kaydedildi: test_image_836.png
# İşlenen görüntüler kaydedildi: test_image_858.png
# İşlenen görüntüler kaydedildi: test_image_863.png
# İşlenen görüntüler kaydedildi: test_image_866.png
# İşlenen görüntüler kaydedildi: test_image_87.png
# İşlenen görüntüler kaydedildi: test_image_870.png
# İşlenen görüntüler kaydedildi: test_image_877.png
# İşlenen görüntüler kaydedildi: test_image_894.png
# İşlenen görüntüler kaydedildi: test_image_913.png
# İşlenen görüntüler kaydedildi: test_image_914.png
# İşlenen görüntüler kaydedildi: test_image_923.png
# İşlenen görüntüler kaydedildi: test_image_926.png
# İşlenen görüntüler kaydedildi: test_image_928.png
# İşlenen görüntüler kaydedildi: test_image_93.png
# İşlenen görüntüler kaydedildi: test_image_942.png
# İşlenen görüntüler kaydedildi: test_image_944.png
# İşlenen görüntüler kaydedildi: test_image_945.png
# İşlenen görüntüler kaydedildi: test_image_947.png
# İşlenen görüntüler kaydedildi: test_image_96.png
# İşlenen görüntüler kaydedildi: test_image_961.png
# İşlenen görüntüler kaydedildi: test_image_969.png
# İşlenen görüntüler kaydedildi: test_image_97.png
# İşlenen görüntüler kaydedildi: test_image_974.png
# İşlenen görüntüler kaydedildi: test_image_98.png
# İşlenen görüntüler kaydedildi: test_image_980.png
# İşlenen görüntüler kaydedildi: test_image_982.png
# İşlenen görüntüler kaydedildi: test_image_993.png
# İşlenen görüntüler kaydedildi: train_image_1.png
# İşlenen görüntüler kaydedildi: train_image_100.png
# İşlenen görüntüler kaydedildi: train_image_1008.png
# İşlenen görüntüler kaydedildi: train_image_1011.png
# İşlenen görüntüler kaydedildi: train_image_1015.png
# İşlenen görüntüler kaydedildi: train_image_1017.png
# İşlenen görüntüler kaydedildi: train_image_1024.png
# İşlenen görüntüler kaydedildi: train_image_1038.png
# İşlenen görüntüler kaydedildi: train_image_1046.png
# İşlenen görüntüler kaydedildi: train_image_1054.png
# İşlenen görüntüler kaydedildi: train_image_1058.png
# İşlenen görüntüler kaydedildi: train_image_1059.png
# İşlenen görüntüler kaydedildi: train_image_1064.png
# İşlenen görüntüler kaydedildi: train_image_107.png
# İşlenen görüntüler kaydedildi: train_image_1074.png
# İşlenen görüntüler kaydedildi: train_image_1077.png
# İşlenen görüntüler kaydedildi: train_image_1082.png
# İşlenen görüntüler kaydedildi: train_image_1086.png
# İşlenen görüntüler kaydedildi: train_image_1087.png
# İşlenen görüntüler kaydedildi: train_image_1096.png
# İşlenen görüntüler kaydedildi: train_image_110.png
# İşlenen görüntüler kaydedildi: train_image_1100.png
# İşlenen görüntüler kaydedildi: train_image_1102.png
# İşlenen görüntüler kaydedildi: train_image_1107.png
# İşlenen görüntüler kaydedildi: train_image_111.png
# İşlenen görüntüler kaydedildi: train_image_1113.png
# İşlenen görüntüler kaydedildi: train_image_1117.png
# İşlenen görüntüler kaydedildi: train_image_1135.png
# İşlenen görüntüler kaydedildi: train_image_1143.png
# İşlenen görüntüler kaydedildi: train_image_1151.png
# İşlenen görüntüler kaydedildi: train_image_1152.png
# İşlenen görüntüler kaydedildi: train_image_1155.png
# İşlenen görüntüler kaydedildi: train_image_1158.png
# İşlenen görüntüler kaydedildi: train_image_1166.png
# İşlenen görüntüler kaydedildi: train_image_117.png
# İşlenen görüntüler kaydedildi: train_image_1170.png
# İşlenen görüntüler kaydedildi: train_image_1171.png
# İşlenen görüntüler kaydedildi: train_image_1174.png
# İşlenen görüntüler kaydedildi: train_image_1178.png
# İşlenen görüntüler kaydedildi: train_image_118.png
# İşlenen görüntüler kaydedildi: train_image_1218.png
# İşlenen görüntüler kaydedildi: train_image_123.png
# İşlenen görüntüler kaydedildi: train_image_1247.png
# İşlenen görüntüler kaydedildi: train_image_1266.png
# İşlenen görüntüler kaydedildi: train_image_1267.png
# İşlenen görüntüler kaydedildi: train_image_1275.png
# İşlenen görüntüler kaydedildi: train_image_1295.png
# İşlenen görüntüler kaydedildi: train_image_1298.png
# İşlenen görüntüler kaydedildi: train_image_1299.png
# İşlenen görüntüler kaydedildi: train_image_1304.png
# İşlenen görüntüler kaydedildi: train_image_1305.png
# İşlenen görüntüler kaydedildi: train_image_1318.png
# İşlenen görüntüler kaydedildi: train_image_1319.png
# İşlenen görüntüler kaydedildi: train_image_1323.png
# İşlenen görüntüler kaydedildi: train_image_1332.png
# İşlenen görüntüler kaydedildi: train_image_1335.png
# İşlenen görüntüler kaydedildi: train_image_1337.png
# İşlenen görüntüler kaydedildi: train_image_1346.png
# İşlenen görüntüler kaydedildi: train_image_1358.png
# İşlenen görüntüler kaydedildi: train_image_1370.png
# İşlenen görüntüler kaydedildi: train_image_1373.png
# İşlenen görüntüler kaydedildi: train_image_1374.png
# İşlenen görüntüler kaydedildi: train_image_138.png
# İşlenen görüntüler kaydedildi: train_image_1387.png
# İşlenen görüntüler kaydedildi: train_image_1394.png
# İşlenen görüntüler kaydedildi: train_image_1399.png
# İşlenen görüntüler kaydedildi: train_image_1406.png
# İşlenen görüntüler kaydedildi: train_image_1410.png
# İşlenen görüntüler kaydedildi: train_image_142.png
# İşlenen görüntüler kaydedildi: train_image_1424.png
# İşlenen görüntüler kaydedildi: train_image_1443.png
# İşlenen görüntüler kaydedildi: train_image_1446.png
# İşlenen görüntüler kaydedildi: train_image_1447.png
# İşlenen görüntüler kaydedildi: train_image_1448.png
# İşlenen görüntüler kaydedildi: train_image_145.png
# İşlenen görüntüler kaydedildi: train_image_1450.png
# İşlenen görüntüler kaydedildi: train_image_1459.png
# İşlenen görüntüler kaydedildi: train_image_1460.png
# İşlenen görüntüler kaydedildi: train_image_1462.png
# İşlenen görüntüler kaydedildi: train_image_147.png
# İşlenen görüntüler kaydedildi: train_image_1472.png
# İşlenen görüntüler kaydedildi: train_image_148.png
# İşlenen görüntüler kaydedildi: train_image_1488.png
# İşlenen görüntüler kaydedildi: train_image_1496.png
# İşlenen görüntüler kaydedildi: train_image_1506.png
# İşlenen görüntüler kaydedildi: train_image_1513.png
# İşlenen görüntüler kaydedildi: train_image_1514.png
# İşlenen görüntüler kaydedildi: train_image_1521.png
# İşlenen görüntüler kaydedildi: train_image_1530.png
# İşlenen görüntüler kaydedildi: train_image_1537.png
# İşlenen görüntüler kaydedildi: train_image_1547.png
# İşlenen görüntüler kaydedildi: train_image_1551.png
# İşlenen görüntüler kaydedildi: train_image_1562.png
# İşlenen görüntüler kaydedildi: train_image_1569.png
# İşlenen görüntüler kaydedildi: train_image_1570.png
# İşlenen görüntüler kaydedildi: train_image_1577.png
# İşlenen görüntüler kaydedildi: train_image_158.png
# İşlenen görüntüler kaydedildi: train_image_1608.png
# İşlenen görüntüler kaydedildi: train_image_1618.png
# İşlenen görüntüler kaydedildi: train_image_1644.png
# İşlenen görüntüler kaydedildi: train_image_1652.png
# İşlenen görüntüler kaydedildi: train_image_1653.png
# İşlenen görüntüler kaydedildi: train_image_1671.png
# İşlenen görüntüler kaydedildi: train_image_168.png
# İşlenen görüntüler kaydedildi: train_image_1690.png
# İşlenen görüntüler kaydedildi: train_image_1699.png
# İşlenen görüntüler kaydedildi: train_image_17.png
# İşlenen görüntüler kaydedildi: train_image_1701.png
# İşlenen görüntüler kaydedildi: train_image_1709.png
# İşlenen görüntüler kaydedildi: train_image_1718.png
# İşlenen görüntüler kaydedildi: train_image_1720.png
# İşlenen görüntüler kaydedildi: train_image_1727.png
# İşlenen görüntüler kaydedildi: train_image_1728.png
# İşlenen görüntüler kaydedildi: train_image_1730.png
# İşlenen görüntüler kaydedildi: train_image_1740.png
# İşlenen görüntüler kaydedildi: train_image_1752.png
# İşlenen görüntüler kaydedildi: train_image_1761.png
# İşlenen görüntüler kaydedildi: train_image_1763.png
# İşlenen görüntüler kaydedildi: train_image_1768.png
# İşlenen görüntüler kaydedildi: train_image_1778.png
# İşlenen görüntüler kaydedildi: train_image_1781.png
# İşlenen görüntüler kaydedildi: train_image_1784.png
# İşlenen görüntüler kaydedildi: train_image_1792.png
# İşlenen görüntüler kaydedildi: train_image_1797.png
# İşlenen görüntüler kaydedildi: train_image_1816.png
# İşlenen görüntüler kaydedildi: train_image_1818.png
# İşlenen görüntüler kaydedildi: train_image_1820.png
# İşlenen görüntüler kaydedildi: train_image_1825.png
# İşlenen görüntüler kaydedildi: train_image_1827.png
# İşlenen görüntüler kaydedildi: train_image_1832.png
# İşlenen görüntüler kaydedildi: train_image_1833.png
# İşlenen görüntüler kaydedildi: train_image_1836.png
# İşlenen görüntüler kaydedildi: train_image_1839.png
# İşlenen görüntüler kaydedildi: train_image_1842.png
# İşlenen görüntüler kaydedildi: train_image_1863.png
# İşlenen görüntüler kaydedildi: train_image_1875.png
# İşlenen görüntüler kaydedildi: train_image_1897.png
# İşlenen görüntüler kaydedildi: train_image_1902.png
# İşlenen görüntüler kaydedildi: train_image_1907.png
# İşlenen görüntüler kaydedildi: train_image_1911.png
# İşlenen görüntüler kaydedildi: train_image_1913.png
# İşlenen görüntüler kaydedildi: train_image_1915.png
# İşlenen görüntüler kaydedildi: train_image_1918.png
# İşlenen görüntüler kaydedildi: train_image_1927.png
# İşlenen görüntüler kaydedildi: train_image_1944.png
# İşlenen görüntüler kaydedildi: train_image_1945.png
# İşlenen görüntüler kaydedildi: train_image_1947.png
# İşlenen görüntüler kaydedildi: train_image_1948.png
# İşlenen görüntüler kaydedildi: train_image_1950.png
# İşlenen görüntüler kaydedildi: train_image_1965.png
# İşlenen görüntüler kaydedildi: train_image_1967.png
# İşlenen görüntüler kaydedildi: train_image_197.png
# İşlenen görüntüler kaydedildi: train_image_1981.png
# İşlenen görüntüler kaydedildi: train_image_1982.png
# İşlenen görüntüler kaydedildi: train_image_1983.png
# İşlenen görüntüler kaydedildi: train_image_199.png
# İşlenen görüntüler kaydedildi: train_image_200.png
# İşlenen görüntüler kaydedildi: train_image_2003.png
# İşlenen görüntüler kaydedildi: train_image_2006.png
# İşlenen görüntüler kaydedildi: train_image_2009.png
# İşlenen görüntüler kaydedildi: train_image_2021.png
# İşlenen görüntüler kaydedildi: train_image_2033.png
# İşlenen görüntüler kaydedildi: train_image_2044.png
# İşlenen görüntüler kaydedildi: train_image_2049.png
# İşlenen görüntüler kaydedildi: train_image_206.png
# İşlenen görüntüler kaydedildi: train_image_207.png
# İşlenen görüntüler kaydedildi: train_image_2077.png
# İşlenen görüntüler kaydedildi: train_image_2079.png
# İşlenen görüntüler kaydedildi: train_image_2085.png
# İşlenen görüntüler kaydedildi: train_image_2092.png
# İşlenen görüntüler kaydedildi: train_image_2095.png
# İşlenen görüntüler kaydedildi: train_image_21.png
# İşlenen görüntüler kaydedildi: train_image_2100.png
# İşlenen görüntüler kaydedildi: train_image_2112.png
# İşlenen görüntüler kaydedildi: train_image_2117.png
# İşlenen görüntüler kaydedildi: train_image_2134.png
# İşlenen görüntüler kaydedildi: train_image_2138.png
# İşlenen görüntüler kaydedildi: train_image_2142.png
# İşlenen görüntüler kaydedildi: train_image_2150.png
# İşlenen görüntüler kaydedildi: train_image_2155.png
# İşlenen görüntüler kaydedildi: train_image_2164.png
# İşlenen görüntüler kaydedildi: train_image_2187.png
# İşlenen görüntüler kaydedildi: train_image_2188.png
# İşlenen görüntüler kaydedildi: train_image_2201.png
# İşlenen görüntüler kaydedildi: train_image_2208.png
# İşlenen görüntüler kaydedildi: train_image_2212.png
# İşlenen görüntüler kaydedildi: train_image_2222.png
# İşlenen görüntüler kaydedildi: train_image_2223.png
# İşlenen görüntüler kaydedildi: train_image_2241.png
# İşlenen görüntüler kaydedildi: train_image_2252.png
# İşlenen görüntüler kaydedildi: train_image_2258.png
# İşlenen görüntüler kaydedildi: train_image_2259.png
# İşlenen görüntüler kaydedildi: train_image_2266.png
# İşlenen görüntüler kaydedildi: train_image_2277.png
# İşlenen görüntüler kaydedildi: train_image_2284.png
# İşlenen görüntüler kaydedildi: train_image_2291.png
# İşlenen görüntüler kaydedildi: train_image_2293.png
# İşlenen görüntüler kaydedildi: train_image_2296.png
# İşlenen görüntüler kaydedildi: train_image_2303.png
# İşlenen görüntüler kaydedildi: train_image_2304.png
# İşlenen görüntüler kaydedildi: train_image_231.png
# İşlenen görüntüler kaydedildi: train_image_2315.png
# İşlenen görüntüler kaydedildi: train_image_233.png
# İşlenen görüntüler kaydedildi: train_image_2331.png
# İşlenen görüntüler kaydedildi: train_image_2334.png
# İşlenen görüntüler kaydedildi: train_image_2336.png
# İşlenen görüntüler kaydedildi: train_image_2339.png
# İşlenen görüntüler kaydedildi: train_image_234.png
# İşlenen görüntüler kaydedildi: train_image_2341.png
# İşlenen görüntüler kaydedildi: train_image_2347.png
# İşlenen görüntüler kaydedildi: train_image_2357.png
# İşlenen görüntüler kaydedildi: train_image_2359.png
# İşlenen görüntüler kaydedildi: train_image_2361.png
# İşlenen görüntüler kaydedildi: train_image_2367.png
# İşlenen görüntüler kaydedildi: train_image_2368.png
# İşlenen görüntüler kaydedildi: train_image_2379.png
# İşlenen görüntüler kaydedildi: train_image_24.png
# İşlenen görüntüler kaydedildi: train_image_2402.png
# İşlenen görüntüler kaydedildi: train_image_2408.png
# İşlenen görüntüler kaydedildi: train_image_2413.png
# İşlenen görüntüler kaydedildi: train_image_2414.png
# İşlenen görüntüler kaydedildi: train_image_2418.png
# İşlenen görüntüler kaydedildi: train_image_2420.png
# İşlenen görüntüler kaydedildi: train_image_2424.png
# İşlenen görüntüler kaydedildi: train_image_2426.png
# İşlenen görüntüler kaydedildi: train_image_2439.png
# İşlenen görüntüler kaydedildi: train_image_2441.png
# İşlenen görüntüler kaydedildi: train_image_2450.png
# İşlenen görüntüler kaydedildi: train_image_2452.png
# İşlenen görüntüler kaydedildi: train_image_2454.png
# İşlenen görüntüler kaydedildi: train_image_2457.png
# İşlenen görüntüler kaydedildi: train_image_2458.png
# İşlenen görüntüler kaydedildi: train_image_246.png
# İşlenen görüntüler kaydedildi: train_image_2460.png
# İşlenen görüntüler kaydedildi: train_image_2468.png
# İşlenen görüntüler kaydedildi: train_image_2469.png
# İşlenen görüntüler kaydedildi: train_image_2474.png
# İşlenen görüntüler kaydedildi: train_image_2489.png
# İşlenen görüntüler kaydedildi: train_image_249.png
# İşlenen görüntüler kaydedildi: train_image_2500.png
# İşlenen görüntüler kaydedildi: train_image_2501.png
# İşlenen görüntüler kaydedildi: train_image_2505.png
# İşlenen görüntüler kaydedildi: train_image_2512.png
# İşlenen görüntüler kaydedildi: train_image_2513.png
# İşlenen görüntüler kaydedildi: train_image_252.png
# İşlenen görüntüler kaydedildi: train_image_2531.png
# İşlenen görüntüler kaydedildi: train_image_2532.png
# İşlenen görüntüler kaydedildi: train_image_255.png
# İşlenen görüntüler kaydedildi: train_image_2553.png
# İşlenen görüntüler kaydedildi: train_image_2558.png
# İşlenen görüntüler kaydedildi: train_image_2559.png
# İşlenen görüntüler kaydedildi: train_image_2564.png
# İşlenen görüntüler kaydedildi: train_image_2565.png
# İşlenen görüntüler kaydedildi: train_image_257.png
# İşlenen görüntüler kaydedildi: train_image_2576.png
# İşlenen görüntüler kaydedildi: train_image_2584.png
# İşlenen görüntüler kaydedildi: train_image_2585.png
# İşlenen görüntüler kaydedildi: train_image_2589.png
# İşlenen görüntüler kaydedildi: train_image_2591.png
# İşlenen görüntüler kaydedildi: train_image_2596.png
# İşlenen görüntüler kaydedildi: train_image_2601.png
# İşlenen görüntüler kaydedildi: train_image_2602.png
# İşlenen görüntüler kaydedildi: train_image_2611.png
# İşlenen görüntüler kaydedildi: train_image_2622.png
# İşlenen görüntüler kaydedildi: train_image_2624.png
# İşlenen görüntüler kaydedildi: train_image_2652.png
# İşlenen görüntüler kaydedildi: train_image_2659.png
# İşlenen görüntüler kaydedildi: train_image_2660.png
# İşlenen görüntüler kaydedildi: train_image_2663.png
# İşlenen görüntüler kaydedildi: train_image_2664.png
# İşlenen görüntüler kaydedildi: train_image_2665.png
# İşlenen görüntüler kaydedildi: train_image_2667.png
# İşlenen görüntüler kaydedildi: train_image_2674.png
# İşlenen görüntüler kaydedildi: train_image_2680.png
# İşlenen görüntüler kaydedildi: train_image_2694.png
# İşlenen görüntüler kaydedildi: train_image_2704.png
# İşlenen görüntüler kaydedildi: train_image_2707.png
# İşlenen görüntüler kaydedildi: train_image_2711.png
# İşlenen görüntüler kaydedildi: train_image_2712.png
# İşlenen görüntüler kaydedildi: train_image_2718.png
# İşlenen görüntüler kaydedildi: train_image_2723.png
# İşlenen görüntüler kaydedildi: train_image_2724.png
# İşlenen görüntüler kaydedildi: train_image_273.png
# İşlenen görüntüler kaydedildi: train_image_2739.png
# İşlenen görüntüler kaydedildi: train_image_2752.png
# İşlenen görüntüler kaydedildi: train_image_2776.png
# İşlenen görüntüler kaydedildi: train_image_2792.png
# İşlenen görüntüler kaydedildi: train_image_2795.png
# İşlenen görüntüler kaydedildi: train_image_2803.png
# İşlenen görüntüler kaydedildi: train_image_2810.png
# İşlenen görüntüler kaydedildi: train_image_282.png
# İşlenen görüntüler kaydedildi: train_image_2821.png
# İşlenen görüntüler kaydedildi: train_image_2830.png
# İşlenen görüntüler kaydedildi: train_image_2832.png
# İşlenen görüntüler kaydedildi: train_image_2839.png
# İşlenen görüntüler kaydedildi: train_image_2840.png
# İşlenen görüntüler kaydedildi: train_image_2844.png
# İşlenen görüntüler kaydedildi: train_image_286.png
# İşlenen görüntüler kaydedildi: train_image_2868.png
# İşlenen görüntüler kaydedildi: train_image_2875.png
# İşlenen görüntüler kaydedildi: train_image_2877.png
# İşlenen görüntüler kaydedildi: train_image_2881.png
# İşlenen görüntüler kaydedildi: train_image_2892.png
# İşlenen görüntüler kaydedildi: train_image_2893.png
# İşlenen görüntüler kaydedildi: train_image_2907.png
# İşlenen görüntüler kaydedildi: train_image_2915.png
# İşlenen görüntüler kaydedildi: train_image_2921.png
# İşlenen görüntüler kaydedildi: train_image_2922.png
# İşlenen görüntüler kaydedildi: train_image_2923.png
# İşlenen görüntüler kaydedildi: train_image_2924.png
# İşlenen görüntüler kaydedildi: train_image_2930.png
# İşlenen görüntüler kaydedildi: train_image_2934.png
# İşlenen görüntüler kaydedildi: train_image_2937.png
# İşlenen görüntüler kaydedildi: train_image_2944.png
# İşlenen görüntüler kaydedildi: train_image_2946.png
# İşlenen görüntüler kaydedildi: train_image_2951.png
# İşlenen görüntüler kaydedildi: train_image_2956.png
# İşlenen görüntüler kaydedildi: train_image_2964.png
# İşlenen görüntüler kaydedildi: train_image_2983.png
# İşlenen görüntüler kaydedildi: train_image_2986.png
# İşlenen görüntüler kaydedildi: train_image_2989.png
# İşlenen görüntüler kaydedildi: train_image_299.png
# İşlenen görüntüler kaydedildi: train_image_2990.png
# İşlenen görüntüler kaydedildi: train_image_2996.png
# İşlenen görüntüler kaydedildi: train_image_2997.png
# İşlenen görüntüler kaydedildi: train_image_30.png
# İşlenen görüntüler kaydedildi: train_image_3011.png
# İşlenen görüntüler kaydedildi: train_image_3014.png
# İşlenen görüntüler kaydedildi: train_image_3018.png
# İşlenen görüntüler kaydedildi: train_image_3019.png
# İşlenen görüntüler kaydedildi: train_image_3025.png
# İşlenen görüntüler kaydedildi: train_image_3028.png
# İşlenen görüntüler kaydedildi: train_image_303.png
# İşlenen görüntüler kaydedildi: train_image_3034.png
# İşlenen görüntüler kaydedildi: train_image_3042.png
# İşlenen görüntüler kaydedildi: train_image_3048.png
# İşlenen görüntüler kaydedildi: train_image_305.png
# İşlenen görüntüler kaydedildi: train_image_3061.png
# İşlenen görüntüler kaydedildi: train_image_3070.png
# İşlenen görüntüler kaydedildi: train_image_3082.png
# İşlenen görüntüler kaydedildi: train_image_310.png
# İşlenen görüntüler kaydedildi: train_image_3103.png
# İşlenen görüntüler kaydedildi: train_image_3107.png
# İşlenen görüntüler kaydedildi: train_image_3112.png
# İşlenen görüntüler kaydedildi: train_image_3119.png
# İşlenen görüntüler kaydedildi: train_image_312.png
# İşlenen görüntüler kaydedildi: train_image_3130.png
# İşlenen görüntüler kaydedildi: train_image_3132.png
# İşlenen görüntüler kaydedildi: train_image_3136.png
# İşlenen görüntüler kaydedildi: train_image_316.png
# İşlenen görüntüler kaydedildi: train_image_3169.png
# İşlenen görüntüler kaydedildi: train_image_3172.png
# İşlenen görüntüler kaydedildi: train_image_3177.png
# İşlenen görüntüler kaydedildi: train_image_3181.png
# İşlenen görüntüler kaydedildi: train_image_3190.png
# İşlenen görüntüler kaydedildi: train_image_3201.png
# İşlenen görüntüler kaydedildi: train_image_3206.png
# İşlenen görüntüler kaydedildi: train_image_3218.png
# İşlenen görüntüler kaydedildi: train_image_322.png
# İşlenen görüntüler kaydedildi: train_image_3224.png
# İşlenen görüntüler kaydedildi: train_image_3242.png
# İşlenen görüntüler kaydedildi: train_image_3247.png
# İşlenen görüntüler kaydedildi: train_image_3250.png
# İşlenen görüntüler kaydedildi: train_image_3252.png
# İşlenen görüntüler kaydedildi: train_image_3259.png
# İşlenen görüntüler kaydedildi: train_image_3266.png
# İşlenen görüntüler kaydedildi: train_image_3267.png
# İşlenen görüntüler kaydedildi: train_image_3274.png
# İşlenen görüntüler kaydedildi: train_image_3295.png
# İşlenen görüntüler kaydedildi: train_image_330.png
# İşlenen görüntüler kaydedildi: train_image_3304.png
# İşlenen görüntüler kaydedildi: train_image_331.png
# İşlenen görüntüler kaydedildi: train_image_3319.png
# İşlenen görüntüler kaydedildi: train_image_334.png
# İşlenen görüntüler kaydedildi: train_image_3347.png
# İşlenen görüntüler kaydedildi: train_image_335.png
# İşlenen görüntüler kaydedildi: train_image_3355.png
# İşlenen görüntüler kaydedildi: train_image_336.png
# İşlenen görüntüler kaydedildi: train_image_3366.png
# İşlenen görüntüler kaydedildi: train_image_3367.png
# İşlenen görüntüler kaydedildi: train_image_3369.png
# İşlenen görüntüler kaydedildi: train_image_337.png
# İşlenen görüntüler kaydedildi: train_image_3372.png
# İşlenen görüntüler kaydedildi: train_image_338.png
# İşlenen görüntüler kaydedildi: train_image_34.png
# İşlenen görüntüler kaydedildi: train_image_340.png
# İşlenen görüntüler kaydedildi: train_image_3407.png
# İşlenen görüntüler kaydedildi: train_image_345.png
# İşlenen görüntüler kaydedildi: train_image_3455.png
# İşlenen görüntüler kaydedildi: train_image_3478.png
# İşlenen görüntüler kaydedildi: train_image_3479.png
# İşlenen görüntüler kaydedildi: train_image_3492.png
# İşlenen görüntüler kaydedildi: train_image_3493.png
# İşlenen görüntüler kaydedildi: train_image_3497.png
# İşlenen görüntüler kaydedildi: train_image_350.png
# İşlenen görüntüler kaydedildi: train_image_3510.png
# İşlenen görüntüler kaydedildi: train_image_3511.png
# İşlenen görüntüler kaydedildi: train_image_3517.png
# İşlenen görüntüler kaydedildi: train_image_3524.png
# İşlenen görüntüler kaydedildi: train_image_3528.png
# İşlenen görüntüler kaydedildi: train_image_3532.png
# İşlenen görüntüler kaydedildi: train_image_3539.png
# İşlenen görüntüler kaydedildi: train_image_3543.png
# İşlenen görüntüler kaydedildi: train_image_3545.png
# İşlenen görüntüler kaydedildi: train_image_3546.png
# İşlenen görüntüler kaydedildi: train_image_3550.png
# İşlenen görüntüler kaydedildi: train_image_3557.png
# İşlenen görüntüler kaydedildi: train_image_3559.png
# İşlenen görüntüler kaydedildi: train_image_3563.png
# İşlenen görüntüler kaydedildi: train_image_3577.png
# İşlenen görüntüler kaydedildi: train_image_3578.png
# İşlenen görüntüler kaydedildi: train_image_3582.png
# İşlenen görüntüler kaydedildi: train_image_3586.png
# İşlenen görüntüler kaydedildi: train_image_359.png
# İşlenen görüntüler kaydedildi: train_image_3590.png
# İşlenen görüntüler kaydedildi: train_image_3600.png
# İşlenen görüntüler kaydedildi: train_image_3612.png
# İşlenen görüntüler kaydedildi: train_image_3624.png
# İşlenen görüntüler kaydedildi: train_image_3633.png
# İşlenen görüntüler kaydedildi: train_image_3636.png
# İşlenen görüntüler kaydedildi: train_image_3641.png
# İşlenen görüntüler kaydedildi: train_image_3642.png
# İşlenen görüntüler kaydedildi: train_image_3649.png
# İşlenen görüntüler kaydedildi: train_image_3654.png
# İşlenen görüntüler kaydedildi: train_image_3656.png
# İşlenen görüntüler kaydedildi: train_image_366.png
# İşlenen görüntüler kaydedildi: train_image_3664.png
# İşlenen görüntüler kaydedildi: train_image_3667.png
# İşlenen görüntüler kaydedildi: train_image_3672.png
# İşlenen görüntüler kaydedildi: train_image_3675.png
# İşlenen görüntüler kaydedildi: train_image_3677.png
# İşlenen görüntüler kaydedildi: train_image_3681.png
# İşlenen görüntüler kaydedildi: train_image_3685.png
# İşlenen görüntüler kaydedildi: train_image_3687.png
# İşlenen görüntüler kaydedildi: train_image_371.png
# İşlenen görüntüler kaydedildi: train_image_3712.png
# İşlenen görüntüler kaydedildi: train_image_3715.png
# İşlenen görüntüler kaydedildi: train_image_3719.png
# İşlenen görüntüler kaydedildi: train_image_3720.png
# İşlenen görüntüler kaydedildi: train_image_3727.png
# İşlenen görüntüler kaydedildi: train_image_373.png
# İşlenen görüntüler kaydedildi: train_image_3730.png
# İşlenen görüntüler kaydedildi: train_image_3743.png
# İşlenen görüntüler kaydedildi: train_image_3766.png
# İşlenen görüntüler kaydedildi: train_image_3774.png
# İşlenen görüntüler kaydedildi: train_image_3777.png
# İşlenen görüntüler kaydedildi: train_image_3779.png
# İşlenen görüntüler kaydedildi: train_image_3783.png
# İşlenen görüntüler kaydedildi: train_image_3785.png
# İşlenen görüntüler kaydedildi: train_image_3787.png
# İşlenen görüntüler kaydedildi: train_image_3790.png
# İşlenen görüntüler kaydedildi: train_image_380.png
# İşlenen görüntüler kaydedildi: train_image_3803.png
# İşlenen görüntüler kaydedildi: train_image_3806.png
# İşlenen görüntüler kaydedildi: train_image_3812.png
# İşlenen görüntüler kaydedildi: train_image_384.png
# İşlenen görüntüler kaydedildi: train_image_3847.png
# İşlenen görüntüler kaydedildi: train_image_3854.png
# İşlenen görüntüler kaydedildi: train_image_3855.png
# İşlenen görüntüler kaydedildi: train_image_3858.png
# İşlenen görüntüler kaydedildi: train_image_3859.png
# İşlenen görüntüler kaydedildi: train_image_386.png
# İşlenen görüntüler kaydedildi: train_image_3862.png
# İşlenen görüntüler kaydedildi: train_image_3866.png
# İşlenen görüntüler kaydedildi: train_image_3888.png
# İşlenen görüntüler kaydedildi: train_image_3890.png
# İşlenen görüntüler kaydedildi: train_image_3900.png
# İşlenen görüntüler kaydedildi: train_image_3901.png
# İşlenen görüntüler kaydedildi: train_image_3911.png
# İşlenen görüntüler kaydedildi: train_image_392.png
# İşlenen görüntüler kaydedildi: train_image_3929.png
# İşlenen görüntüler kaydedildi: train_image_3937.png
# İşlenen görüntüler kaydedildi: train_image_3953.png
# İşlenen görüntüler kaydedildi: train_image_3972.png
# İşlenen görüntüler kaydedildi: train_image_3978.png
# İşlenen görüntüler kaydedildi: train_image_3987.png
# İşlenen görüntüler kaydedildi: train_image_3989.png
# İşlenen görüntüler kaydedildi: train_image_399.png
# İşlenen görüntüler kaydedildi: train_image_3991.png
# İşlenen görüntüler kaydedildi: train_image_4010.png
# İşlenen görüntüler kaydedildi: train_image_4013.png
# İşlenen görüntüler kaydedildi: train_image_4021.png
# İşlenen görüntüler kaydedildi: train_image_4047.png
# İşlenen görüntüler kaydedildi: train_image_4052.png
# İşlenen görüntüler kaydedildi: train_image_4065.png
# İşlenen görüntüler kaydedildi: train_image_407.png
# İşlenen görüntüler kaydedildi: train_image_4073.png
# İşlenen görüntüler kaydedildi: train_image_4075.png
# İşlenen görüntüler kaydedildi: train_image_408.png
# İşlenen görüntüler kaydedildi: train_image_4095.png
# İşlenen görüntüler kaydedildi: train_image_4113.png
# İşlenen görüntüler kaydedildi: train_image_4124.png
# İşlenen görüntüler kaydedildi: train_image_4132.png
# İşlenen görüntüler kaydedildi: train_image_4138.png
# İşlenen görüntüler kaydedildi: train_image_4139.png
# İşlenen görüntüler kaydedildi: train_image_4140.png
# İşlenen görüntüler kaydedildi: train_image_4145.png
# İşlenen görüntüler kaydedildi: train_image_4146.png
# İşlenen görüntüler kaydedildi: train_image_4151.png
# İşlenen görüntüler kaydedildi: train_image_4157.png
# İşlenen görüntüler kaydedildi: train_image_4159.png
# İşlenen görüntüler kaydedildi: train_image_416.png
# İşlenen görüntüler kaydedildi: train_image_4160.png
# İşlenen görüntüler kaydedildi: train_image_4162.png
# İşlenen görüntüler kaydedildi: train_image_4164.png
# İşlenen görüntüler kaydedildi: train_image_4171.png
# İşlenen görüntüler kaydedildi: train_image_4175.png
# İşlenen görüntüler kaydedildi: train_image_4182.png
# İşlenen görüntüler kaydedildi: train_image_4199.png
# İşlenen görüntüler kaydedildi: train_image_4210.png
# İşlenen görüntüler kaydedildi: train_image_4211.png
# İşlenen görüntüler kaydedildi: train_image_4220.png
# İşlenen görüntüler kaydedildi: train_image_4232.png
# İşlenen görüntüler kaydedildi: train_image_4248.png
# İşlenen görüntüler kaydedildi: train_image_4249.png
# İşlenen görüntüler kaydedildi: train_image_4251.png
# İşlenen görüntüler kaydedildi: train_image_4258.png
# İşlenen görüntüler kaydedildi: train_image_4260.png
# İşlenen görüntüler kaydedildi: train_image_4265.png
# İşlenen görüntüler kaydedildi: train_image_4268.png
# İşlenen görüntüler kaydedildi: train_image_4270.png
# İşlenen görüntüler kaydedildi: train_image_4279.png
# İşlenen görüntüler kaydedildi: train_image_4285.png
# İşlenen görüntüler kaydedildi: train_image_4288.png
# İşlenen görüntüler kaydedildi: train_image_4292.png
# İşlenen görüntüler kaydedildi: train_image_430.png
# İşlenen görüntüler kaydedildi: train_image_4302.png
# İşlenen görüntüler kaydedildi: train_image_4310.png
# İşlenen görüntüler kaydedildi: train_image_4311.png
# İşlenen görüntüler kaydedildi: train_image_4312.png
# İşlenen görüntüler kaydedildi: train_image_4320.png
# İşlenen görüntüler kaydedildi: train_image_4349.png
# İşlenen görüntüler kaydedildi: train_image_4357.png
# İşlenen görüntüler kaydedildi: train_image_4368.png
# İşlenen görüntüler kaydedildi: train_image_4373.png
# İşlenen görüntüler kaydedildi: train_image_4378.png
# İşlenen görüntüler kaydedildi: train_image_4381.png
# İşlenen görüntüler kaydedildi: train_image_4399.png
# İşlenen görüntüler kaydedildi: train_image_440.png
# İşlenen görüntüler kaydedildi: train_image_4404.png
# İşlenen görüntüler kaydedildi: train_image_441.png
# İşlenen görüntüler kaydedildi: train_image_4413.png
# İşlenen görüntüler kaydedildi: train_image_4420.png
# İşlenen görüntüler kaydedildi: train_image_4423.png
# İşlenen görüntüler kaydedildi: train_image_4425.png
# İşlenen görüntüler kaydedildi: train_image_4430.png
# İşlenen görüntüler kaydedildi: train_image_4455.png
# İşlenen görüntüler kaydedildi: train_image_4456.png
# İşlenen görüntüler kaydedildi: train_image_4462.png
# İşlenen görüntüler kaydedildi: train_image_4465.png
# İşlenen görüntüler kaydedildi: train_image_4510.png
# İşlenen görüntüler kaydedildi: train_image_4534.png
# İşlenen görüntüler kaydedildi: train_image_454.png
# İşlenen görüntüler kaydedildi: train_image_4540.png
# İşlenen görüntüler kaydedildi: train_image_4549.png
# İşlenen görüntüler kaydedildi: train_image_4551.png
# İşlenen görüntüler kaydedildi: train_image_4552.png
# İşlenen görüntüler kaydedildi: train_image_4553.png
# İşlenen görüntüler kaydedildi: train_image_4557.png
# İşlenen görüntüler kaydedildi: train_image_456.png
# İşlenen görüntüler kaydedildi: train_image_4565.png
# İşlenen görüntüler kaydedildi: train_image_4602.png
# İşlenen görüntüler kaydedildi: train_image_4610.png
# İşlenen görüntüler kaydedildi: train_image_4617.png
# İşlenen görüntüler kaydedildi: train_image_4631.png
# İşlenen görüntüler kaydedildi: train_image_4636.png
# İşlenen görüntüler kaydedildi: train_image_4644.png
# İşlenen görüntüler kaydedildi: train_image_465.png
# İşlenen görüntüler kaydedildi: train_image_4656.png
# İşlenen görüntüler kaydedildi: train_image_4658.png
# İşlenen görüntüler kaydedildi: train_image_4687.png
# İşlenen görüntüler kaydedildi: train_image_4695.png
# İşlenen görüntüler kaydedildi: train_image_470.png
# İşlenen görüntüler kaydedildi: train_image_4700.png
# İşlenen görüntüler kaydedildi: train_image_4701.png
# İşlenen görüntüler kaydedildi: train_image_4703.png
# İşlenen görüntüler kaydedildi: train_image_4717.png
# İşlenen görüntüler kaydedildi: train_image_4734.png
# İşlenen görüntüler kaydedildi: train_image_4741.png
# İşlenen görüntüler kaydedildi: train_image_4744.png
# İşlenen görüntüler kaydedildi: train_image_4748.png
# İşlenen görüntüler kaydedildi: train_image_4749.png
# İşlenen görüntüler kaydedildi: train_image_4752.png
# İşlenen görüntüler kaydedildi: train_image_4754.png
# İşlenen görüntüler kaydedildi: train_image_4760.png
# İşlenen görüntüler kaydedildi: train_image_4767.png
# İşlenen görüntüler kaydedildi: train_image_4779.png
# İşlenen görüntüler kaydedildi: train_image_478.png
# İşlenen görüntüler kaydedildi: train_image_4783.png
# İşlenen görüntüler kaydedildi: train_image_4784.png
# İşlenen görüntüler kaydedildi: train_image_4791.png
# İşlenen görüntüler kaydedildi: train_image_4793.png
# İşlenen görüntüler kaydedildi: train_image_4802.png
# İşlenen görüntüler kaydedildi: train_image_4808.png
# İşlenen görüntüler kaydedildi: train_image_481.png
# İşlenen görüntüler kaydedildi: train_image_4810.png
# İşlenen görüntüler kaydedildi: train_image_4816.png
# İşlenen görüntüler kaydedildi: train_image_4817.png
# İşlenen görüntüler kaydedildi: train_image_482.png
# İşlenen görüntüler kaydedildi: train_image_4831.png
# İşlenen görüntüler kaydedildi: train_image_4837.png
# İşlenen görüntüler kaydedildi: train_image_4838.png
# İşlenen görüntüler kaydedildi: train_image_484.png
# İşlenen görüntüler kaydedildi: train_image_4843.png
# İşlenen görüntüler kaydedildi: train_image_4846.png
# İşlenen görüntüler kaydedildi: train_image_4847.png
# İşlenen görüntüler kaydedildi: train_image_4857.png
# İşlenen görüntüler kaydedildi: train_image_4860.png
# İşlenen görüntüler kaydedildi: train_image_4861.png
# İşlenen görüntüler kaydedildi: train_image_4865.png
# İşlenen görüntüler kaydedildi: train_image_4867.png
# İşlenen görüntüler kaydedildi: train_image_4870.png
# İşlenen görüntüler kaydedildi: train_image_4875.png
# İşlenen görüntüler kaydedildi: train_image_488.png
# İşlenen görüntüler kaydedildi: train_image_4884.png
# İşlenen görüntüler kaydedildi: train_image_4892.png
# İşlenen görüntüler kaydedildi: train_image_4896.png
# İşlenen görüntüler kaydedildi: train_image_4939.png
# İşlenen görüntüler kaydedildi: train_image_4946.png
# İşlenen görüntüler kaydedildi: train_image_4948.png
# İşlenen görüntüler kaydedildi: train_image_4966.png
# İşlenen görüntüler kaydedildi: train_image_4969.png
# İşlenen görüntüler kaydedildi: train_image_5001.png
# İşlenen görüntüler kaydedildi: train_image_5014.png
# İşlenen görüntüler kaydedildi: train_image_5017.png
# İşlenen görüntüler kaydedildi: train_image_5025.png
# İşlenen görüntüler kaydedildi: train_image_5031.png
# İşlenen görüntüler kaydedildi: train_image_5041.png
# İşlenen görüntüler kaydedildi: train_image_5049.png
# İşlenen görüntüler kaydedildi: train_image_5052.png
# İşlenen görüntüler kaydedildi: train_image_5054.png
# İşlenen görüntüler kaydedildi: train_image_5057.png
# İşlenen görüntüler kaydedildi: train_image_5060.png
# İşlenen görüntüler kaydedildi: train_image_5064.png
# İşlenen görüntüler kaydedildi: train_image_5068.png
# İşlenen görüntüler kaydedildi: train_image_5083.png
# İşlenen görüntüler kaydedildi: train_image_5088.png
# İşlenen görüntüler kaydedildi: train_image_5095.png
# İşlenen görüntüler kaydedildi: train_image_5097.png
# İşlenen görüntüler kaydedildi: train_image_5099.png
# İşlenen görüntüler kaydedildi: train_image_510.png
# İşlenen görüntüler kaydedildi: train_image_5109.png
# İşlenen görüntüler kaydedildi: train_image_5118.png
# İşlenen görüntüler kaydedildi: train_image_516.png
# İşlenen görüntüler kaydedildi: train_image_518.png
# İşlenen görüntüler kaydedildi: train_image_522.png
# İşlenen görüntüler kaydedildi: train_image_524.png
# İşlenen görüntüler kaydedildi: train_image_530.png
# İşlenen görüntüler kaydedildi: train_image_554.png
# İşlenen görüntüler kaydedildi: train_image_557.png
# İşlenen görüntüler kaydedildi: train_image_561.png
# İşlenen görüntüler kaydedildi: train_image_572.png
# İşlenen görüntüler kaydedildi: train_image_578.png
# İşlenen görüntüler kaydedildi: train_image_581.png
# İşlenen görüntüler kaydedildi: train_image_597.png
# İşlenen görüntüler kaydedildi: train_image_603.png
# İşlenen görüntüler kaydedildi: train_image_610.png
# İşlenen görüntüler kaydedildi: train_image_627.png
# İşlenen görüntüler kaydedildi: train_image_637.png
# İşlenen görüntüler kaydedildi: train_image_642.png
# İşlenen görüntüler kaydedildi: train_image_650.png
# İşlenen görüntüler kaydedildi: train_image_651.png
# İşlenen görüntüler kaydedildi: train_image_654.png
# İşlenen görüntüler kaydedildi: train_image_657.png
# İşlenen görüntüler kaydedildi: train_image_662.png
# İşlenen görüntüler kaydedildi: train_image_663.png
# İşlenen görüntüler kaydedildi: train_image_67.png
# İşlenen görüntüler kaydedildi: train_image_671.png
# İşlenen görüntüler kaydedildi: train_image_679.png
# İşlenen görüntüler kaydedildi: train_image_682.png
# İşlenen görüntüler kaydedildi: train_image_686.png
# İşlenen görüntüler kaydedildi: train_image_69.png
# İşlenen görüntüler kaydedildi: train_image_701.png
# İşlenen görüntüler kaydedildi: train_image_712.png
# İşlenen görüntüler kaydedildi: train_image_714.png
# İşlenen görüntüler kaydedildi: train_image_728.png
# İşlenen görüntüler kaydedildi: train_image_73.png
# İşlenen görüntüler kaydedildi: train_image_731.png
# İşlenen görüntüler kaydedildi: train_image_733.png
# İşlenen görüntüler kaydedildi: train_image_738.png
# İşlenen görüntüler kaydedildi: train_image_739.png
# İşlenen görüntüler kaydedildi: train_image_749.png
# İşlenen görüntüler kaydedildi: train_image_751.png
# İşlenen görüntüler kaydedildi: train_image_772.png
# İşlenen görüntüler kaydedildi: train_image_773.png
# İşlenen görüntüler kaydedildi: train_image_780.png
# İşlenen görüntüler kaydedildi: train_image_787.png
# İşlenen görüntüler kaydedildi: train_image_788.png
# İşlenen görüntüler kaydedildi: train_image_799.png
# İşlenen görüntüler kaydedildi: train_image_800.png
# İşlenen görüntüler kaydedildi: train_image_803.png
# İşlenen görüntüler kaydedildi: train_image_805.png
# İşlenen görüntüler kaydedildi: train_image_807.png
# İşlenen görüntüler kaydedildi: train_image_814.png
# İşlenen görüntüler kaydedildi: train_image_820.png
# İşlenen görüntüler kaydedildi: train_image_823.png
# İşlenen görüntüler kaydedildi: train_image_837.png
# İşlenen görüntüler kaydedildi: train_image_840.png
# İşlenen görüntüler kaydedildi: train_image_85.png
# İşlenen görüntüler kaydedildi: train_image_850.png
# İşlenen görüntüler kaydedildi: train_image_851.png
# İşlenen görüntüler kaydedildi: train_image_853.png
# İşlenen görüntüler kaydedildi: train_image_856.png
# İşlenen görüntüler kaydedildi: train_image_858.png
# İşlenen görüntüler kaydedildi: train_image_861.png
# İşlenen görüntüler kaydedildi: train_image_870.png
# İşlenen görüntüler kaydedildi: train_image_876.png
# İşlenen görüntüler kaydedildi: train_image_889.png
# İşlenen görüntüler kaydedildi: train_image_895.png
# İşlenen görüntüler kaydedildi: train_image_897.png
# İşlenen görüntüler kaydedildi: train_image_898.png
# İşlenen görüntüler kaydedildi: train_image_899.png
# İşlenen görüntüler kaydedildi: train_image_90.png
# İşlenen görüntüler kaydedildi: train_image_906.png
# İşlenen görüntüler kaydedildi: train_image_916.png
# İşlenen görüntüler kaydedildi: train_image_929.png
# İşlenen görüntüler kaydedildi: train_image_94.png
# İşlenen görüntüler kaydedildi: train_image_946.png
# İşlenen görüntüler kaydedildi: train_image_948.png
# İşlenen görüntüler kaydedildi: train_image_959.png
# İşlenen görüntüler kaydedildi: train_image_963.png
# İşlenen görüntüler kaydedildi: train_image_989.png
# İşlenen görüntüler kaydedildi: train_image_99.png
# İşlenen görüntüler kaydedildi: train_image_992.png

# %%
    import os
    import cv2
    import numpy as np
    import matplotlib.pyplot as plt

    # Resimlerin bulunduğu dizin
    input_dir = 'processed/3'
    output_dir = 'processed/3'  # Aynı dizine yazmak için aynı dizini kullanıyoruz

    # Dizindeki tüm resim dosyalarını listeleme
    image_files = [f for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]

    for image_file in image_files:
        image_path = os.path.join(input_dir, image_file)
        mr_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Görüntüyü bulanıklaştırma
        blurred = cv2.GaussianBlur(mr_image, (5, 5), 0)

        # İkili (binary) görüntü oluşturma
        _, binary_image = cv2.threshold(blurred, 30, 255, cv2.THRESH_BINARY)

        # Konturları bulma
        contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

        if contours:
            # En büyük konturu (beyin) bulma
            largest_contour = max(contours, key=cv2.contourArea)

            # En büyük konturun etrafındaki dikdörtgeni bulma
            x, y, w, h = cv2.boundingRect(largest_contour)

            # Beyin bölgesini kırpma
            cropped_image = mr_image[y:y+h, x:x+w]

            # Kırpılmış görüntüyü kaydetme (eski resmin üzerine yazma)
            cv2.imwrite(image_path, cropped_image)

        else:
            print(f"Kontur bulunamadı: {image_file}")

    print("Tüm resimler başarıyla işlendi ve kaydedildi.")
# Out:
# Tüm resimler başarıyla işlendi ve kaydedildi.

# %%
import cv2
import os

def resize_images(input_folder, output_folder, target_size):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(".png") or filename.endswith(".jpg"):
            img = cv2.imread(os.path.join(input_folder, filename))
            resized_img = cv2.resize(img, target_size)
            cv2.imwrite(os.path.join(output_folder, filename), resized_img)

input_folder = 'ham/label_3'
output_folder = 'ham/label_3'
target_size = (256, 256)  # Hedef boyut (genişlik, yükseklik)
resize_images(input_folder, output_folder, target_size)

# %%
"""import numpy as np
import skimage.io as io
import skimage.feature as feature
import skimage.measure as measure
from skimage.filters import sobel

# MR görüntüsünü yükleme
image = io.imread('C:/Users/osman/OneDrive/Masaüstü/vs/ham/label_0/test_image_1.png', as_gray=True)

# Görüntüyü uint8 tipine dönüştürme
image = (image * 255).astype(np.uint8)

# Yoğunluk temelli özellikler
mean_intensity = np.mean(image)
std_intensity = np.std(image)
min_intensity = np.min(image)
max_intensity = np.max(image)

# GLCM özellikleri
glcm = feature.graycomatrix(image, distances=[5], angles=[0], symmetric=True, normed=True)
contrast = feature.graycoprops(glcm, 'contrast')[0, 0]
correlation = feature.graycoprops(glcm, 'correlation')[0, 0]
energy = feature.graycoprops(glcm, 'energy')[0, 0]
homogeneity = feature.graycoprops(glcm, 'homogeneity')[0, 0]

# Şekil özellikleri
edges = sobel(image)
contours = measure.find_contours(edges, 0.8)
props = measure.regionprops(edges.astype(int))

# Bölgenin birden fazla olabileceği durumu göz önünde bulundurmak için bir kontrol ekliyoruz.
if len(props) > 0:
    area = props[0].area
    perimeter = props[0].perimeter
else:
    area = 0
    perimeter = 0

# Çıkarılan özelliklerin yazdırılması
print(f"Mean Intensity: {mean_intensity}")
print(f"Standard Deviation: {std_intensity}")
print(f"Minimum Intensity: {min_intensity}")
print(f"Maximum Intensity: {max_intensity}")
print(f"GLCM Contrast: {contrast}")
print(f"GLCM Correlation: {correlation}")
print(f"GLCM Energy: {energy}")
print(f"GLCM Homogeneity: {homogeneity}")
print(f"Area: {area}")
print(f"Perimeter: {perimeter}")
"""
# Out:
# Mean Intensity: 111.06971740722656
# Standard Deviation: 84.21904554653456
# Minimum Intensity: 0
# Maximum Intensity: 252
# GLCM Contrast: 1337.1104177041832
# GLCM Correlation: 0.9047208722605139
# GLCM Energy: 0.10530391600672052
# GLCM Homogeneity: 0.18512885235268284
# Area: 0
# Perimeter: 0
